# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display, HTML
from mpl_toolkits.mplot3d import Axes3D

adhd1 = pd.read_csv("data/TAIWAN_RAW_DATA/ADHD/A2_886001_20170227_184017/filtered_A2RealTime_886001_20170227_184017.csv") # has no hands and feet data
adhd2 = pd.read_csv("data/TAIWAN_RAW_DATA/ADHD/A2_886002_20170228_104813/filtered_A2RealTime_886002_20170228_104813.csv")#has not hands and feet data
adhd3 = pd.read_csv("data/TAIWAN_RAW_DATA/ADHD/A2_886006_20170304_172008/filtered_A2RealTime_886006_20170304_172008.csv")
adhd4 = pd.read_csv("data/TAIWAN_RAW_DATA/ADHD/A2_886010_20170305_132607/filtered_A2RealTime_886010_20170305_132607.csv")
adhd5 = pd.read_csv("data/TAIWAN_RAW_DATA/ADHD/A2_886015_20170311_153739/A2RealTime_886015_20170311_153739.csv")
adhd6 = pd.read_csv("data/TAIWAN_RAW_DATA/ADHD/A2_886016_20170311_184832/A2RealTime_886016_20170311_184832.csv")
adhd7 = pd.read_csv("data/TAIWAN_RAW_DATA/ADHD/A2_886017_20170312_112519/A2RealTime_886017_20170312_112519.csv")
adhd8 = pd.read_csv("data/TAIWAN_RAW_DATA/ADHD/A2_886018_20170317_192755/A2RealTime_886018_20170317_192755.csv")
adhd9 = pd.read_csv("data/TAIWAN_RAW_DATA/ADHD/A2_886019_20170318_130057/A2RealTime_886019_20170318_130057.csv")
adhd10 =  pd.read_csv("data/TAIWAN_RAW_DATA/ADHD/A2_886020_20170318_135002/A2RealTime_886020_20170318_135002.csv")
healthy1 = pd.read_csv("data/TAIWAN_RAW_DATA/HEALTHY/A2_886003_20170228_130925/filtered_A2RealTime_886003_20170228_130925.csv")
healthy2 = pd.read_csv("data/TAIWAN_RAW_DATA/HEALTHY/A2_886004_20170304_152912/filtered_A2RealTime_886004_20170304_152912.csv")
healthy3 = pd.read_csv("data/TAIWAN_RAW_DATA/HEALTHY/A2_886005_20170304_160532/filtered_A2RealTime_886005_20170304_160532.csv")
healthy4 = pd.read_csv("data/TAIWAN_RAW_DATA/HEALTHY/A2_886007_20170305_102310/filtered_A2RealTime_886007_20170305_102310.csv")
healthy5 = pd.read_csv("data/TAIWAN_RAW_DATA/HEALTHY/A2_886008_20170305_105348/filtered_A2RealTime_886008_20170305_105348.csv")
healthy6 = pd.read_csv("data/TAIWAN_RAW_DATA/HEALTHY/A2_886009_20170305_112726/filtered_A2RealTime_886009_20170305_112726.csv")
healthy7 = pd.read_csv("data/TAIWAN_RAW_DATA/HEALTHY/A2_886011_20170309_190528/filtered_A2RealTime_886011_20170309_190528.csv")
healthy8 = pd.read_csv("data/TAIWAN_RAW_DATA/HEALTHY/A2_886012_20170309_193106/filtered_A2RealTime_886012_20170309_193106.csv")
healthy9 = pd.read_csv("data/TAIWAN_RAW_DATA/HEALTHY/A2_886013_20170309_200214/filtered_A2RealTime_886013_20170309_200214.csv")
healthy10 = pd.read_csv("data/TAIWAN_RAW_DATA/HEALTHY/A2_886014_20170309_205449/filtered_A2RealTime_886014_20170309_205449.csv")
#adhd.set_index("Time", inplace = True);
display(healthy7)
#ADHD = [adhd1, adhd2, adhd3, adhd4, adhd5, adhd6, adhd7]
ADHD = [adhd8, adhd9, adhd10]
HEALTHY = [healthy1, healthy2, healthy3, healthy4, healthy5, healthy6, healthy7, healthy8, healthy9, healthy10]
#ADHDnum = ["001", "002", "006", "010", "015", "016", "017",]
ADHDnum =["018", "019", "020"]
HEALTHYnum = ["003", "004", "005", "007", "008", "009", "011", "012", "013", "014"]
# Out:
#        Unnamed: 0                 Time  Block  Sti  Hit      PosX      PosY  \
# 0               0  20170309-190528-097      1    J    0  0.022610  0.476003
# 1               1  20170309-190528-130      1    J    0  0.059468  1.252170
# 2               2  20170309-190528-152      1    J    0  0.055412  1.167776
# 3               3  20170309-190528-163      1    J    0  0.046114  0.973964
# 4               4  20170309-190528-185      1    J    0  0.056603  1.196886
# 5               5  20170309-190528-208      1    J    0  0.050083  1.060794
# 6               6  20170309-190528-230      1    J    0  0.051314  1.087631
# 7               7  20170309-190528-252      1  NaN    0  0.053730  1.140017
# 8               8  20170309-190528-275      1  NaN    0  0.049675  1.055349
# 9               9  20170309-190528-286      1  NaN    0  0.053311  1.131897
# 10             10  20170309-190528-309      1  NaN    0  0.051180  1.086285
# ...

# %%
for i in range(len(HEALTHY)):
    fig = plt.figure()
    axrot = fig.add_subplot(111)
    axrot.plot(HEALTHY[i]['RotX'],HEALTHY[i]['RotY'])
    axrot.set_xlim(-50, 400)
    axrot.set_ylim(-50, 400)
    plt.gca().set_aspect('equal', adjustable='box')
    plt.title("Head Rotation for HealthyKid" + str(i+1) + "(filtered)")
    plt.savefig("Head Rotation for HealthyKid" + str(i+1) + "(filtered)")

# %%
for i in range(len(ADHD)):
    fig = plt.figure()
    axrot = fig.add_subplot(111)
    axrot.plot(ADHD[i]['RotX'],ADHD[i]['RotY'])
    axrot.set_xlim(-50, 400)
    axrot.set_ylim(-50, 400)
    plt.gca().set_aspect('equal', adjustable='box')
    plt.title("Head Rotation for ADHDKid" + str(i+1) + "(filtered)")
    plt.savefig("Head Rotation for ADHDKid" + str(i+1) + "(filtered)")

# %%
fig = plt.figure()
axhealthy2rot = fig.add_subplot(111, projection='3d')
axhealthy2rot.plot(healthy2['RotX'],healthy2['RotY'])
plt.show()

# %%
for i in range(len(HEALTHY)):
    fig = plt.figure()
    axpos = fig.add_subplot(111, projection='3d')
    axpos.plot(HEALTHY[i]['PosX'].tolist()[5:],HEALTHY[i]['PosY'].tolist()[5:], HEALTHY[i]['PosZ'].tolist()[5:])
    axpos.set_xlim([-0.8, 0.4])
    axpos.set_ylim([1.0, 1.4])
    axpos.set_zlim([-3.0, -2.0])
    plt.title("Head Position of Subject " + HEALTHYnum[i] + " (Healthy)")
    #plt.show()
    plt.savefig("Head Position of Subject " + HEALTHYnum[i] + " (Healthy)")

# %%
for i in range(len(ADHD)):
    fig = plt.figure()
    axpos = fig.add_subplot(111, projection='3d')
    axpos.plot(ADHD[i]['PosX'].tolist()[5:],ADHD[i]['PosY'].tolist()[5:], ADHD[i]['PosZ'].tolist()[5:])
    axpos.set_xlim(-0.8, 0.4)
    axpos.set_ylim(1.0, 1.4)
    axpos.set_zlim(-3.0, -2.0)
    plt.title("Head Position of Subject " + ADHDnum[i] + " (ADHD)")
    #plt.show()
    
    plt.savefig("Head Position of Subject " + ADHDnum[i] + " (ADHD)")

# %%
for number in healthy7['PosX']:
    if number < 0:
       print(number)

# %%
i = 5
fig = plt.figure()
axpos = fig.add_subplot(111, projection='3d')
a = HEALTHY[i]['PosX'].tolist()
b = HEALTHY[i]['PosY'].tolist()
c = HEALTHY[i]['PosZ'].tolist()
axpos.plot(a[5:], b[5:], c[5:])
axpos.set_xlim(-0.8, 0.4)
axpos.set_ylim(1.0, 1.4)
axpos.set_zlim([-3.0, -2.0])
plt.title("Head Position for HealthyKid" + str(i+1) + "(filtered)")
plt.show()
